# %% [markdown]
# # Red Wine Quality
#
# ## Input variables (based on physicochemical tests):
#
# 1 - fixed acidity
# 2 - volatile acidity
# 3 - citric acid
# 4 - residual sugar
# 5 - chlorides
# 6 - free sulfur dioxide
# 7 - total sulfur dioxide
# 8 - density
# 9 - pH
# 10 - sulphates
# 11 - alcohol
# Output variable (based on sensory data):
# 12 - quality (score between 0 and 10)

# %% [markdown]
# Import Library

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# Read CSV

# %%
df = pd.read_csv('winequality-red.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
df.isnull().sum()
# Hence there is no missing value in the dataset
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.dtypes
# There are all numerical and float data types
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.corr().T
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %% [markdown]
# EDA

# %%
annot = True
sns.heatmap(df.corr(), annot = annot)

# %% [markdown]
# Negatively correlated:
# ph and fixed acidity, citric acid and ph,citric acid and volatile acidity

# %%
df = df.drop(['pH'], axis = 1)

# %%
df.hist(figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc69236ea00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6922f2190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc69231a8e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc6922c80a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc69227a760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc692228dc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc692228eb0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc698f6f8b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6923d6550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fc69232ec70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc6923fe310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fc69242c610>]],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
sns.scatterplot(x = 'fixed acidity', y = 'quality', data = df)
plt.show()
# fixed acidity should be between 2 to 12 for the better quality of wine

# %%
sns.scatterplot(x = 'volatile acidity', y = 'quality', data = df)
plt.show()
# volatile acidity should be between 0.2 to 1.0 for the better quality of wine

# %%
sns.scatterplot(x = 'chlorides', y = 'quality', data = df)
plt.show()
# lesser the percentage of chloride better the quality of wine

# %%
sns.scatterplot(x = 'density', y = 'quality', data = df)
plt.show()

# %%
sns.scatterplot(x = 'residual sugar', y = 'quality', data = df)
plt.show()

# %%
sns.boxplot(x = 'quality', y = 'density', data = df)

# %% [markdown]
# # Deciding dependent and independant variables

# %%
X = df.drop(['quality'], axis=1)

y = df['quality']

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33)

# %% [markdown]
# ## Training a Decision Tree Model
#
# Let's start by training a single decision tree first!
#
# ** Import DecisionTreeClassifier**

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# **Create an instance of DecisionTreeClassifier() called dtree and fit it to the training data.**

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Predictions and Evaluation of Decision Tree
# **Create predictions from the test set and create a classification report and a confusion matrix.**

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.20      0.20      0.20        15
#            5       0.71      0.72      0.72       228
#            6       0.65      0.62      0.64       216
#            7       0.50      0.52      0.51        60
#            8       0.17      0.14      0.15         7
#
#     accuracy                           0.63       528
#    macro avg       0.37      0.37      0.37       528
# weighted avg       0.64      0.63      0.64       528

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[  0   0   1   1   0   0]
#  [  0   3   9   3   0   0]
#  [  3   7 165  49   4   0]
#  [  1   5  50 135  23   2]
#  [  0   0   7  19  31   3]
#  [  0   0   1   1   4   1]]

# %% [markdown]
# ## Training the Random Forest model
#
# Now its time to train our model!
#
# **Create an instance of the RandomForestClassifier class and fit it to our training data from the previous step.**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=600)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=600)

# %% [markdown]
# ## Predictions and Evaluation
#
# Let's predict off the y_test values and evaluate our model.
#
# ** Predict the class of not.fully.paid for the X_test data.**

# %%
predictions = rfc.predict(X_test)

# %% [markdown]
# **Now create a classification report from the results. Do you get anything
#
# ---
#
# strange or some sort of warning?**

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        15
#            5       0.75      0.77      0.76       228
#            6       0.64      0.72      0.68       216
#            7       0.60      0.45      0.51        60
#            8       1.00      0.14      0.25         7
#
#     accuracy                           0.68       528
#    macro avg       0.50      0.35      0.37       528
# weighted avg       0.66      0.68      0.67       528
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Show the Confusion Matrix for the predictions.

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[  0   0   1   1   0   0]
#  [  0   0  12   3   0   0]
#  [  0   0 176  50   2   0]
#  [  0   1  47 156  12   0]
#  [  0   0   0  33  27   0]
#  [  0   0   0   2   4   1]]

# %%
# instantiate the DecisionTreeClassifier model with criterion gini index
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)
plt.figure(figsize=(20,12))
from sklearn import tree
tree.plot_tree(clf_gini.fit(X_train, y_train))
# Out:
# [Text(0.5, 0.875, 'X[9] <= 10.525\ngini = 0.648\nsamples = 1071\nvalue = [8, 38, 453, 422, 139, 11]'),
#  Text(0.25, 0.625, 'X[8] <= 0.575\ngini = 0.54\nsamples = 655\nvalue = [5, 22, 386, 217, 24, 1]'),
#  Text(0.125, 0.375, 'X[9] <= 9.533\ngini = 0.423\nsamples = 264\nvalue = [4, 12, 193, 53, 2, 0]'),
#  Text(0.0625, 0.125, 'gini = 0.265\nsamples = 132\nvalue = [1, 2, 112, 16, 1, 0]'),
#  Text(0.1875, 0.125, 'gini = 0.539\nsamples = 132\nvalue = [3, 10, 81, 37, 1, 0]'),
#  Text(0.375, 0.375, 'X[6] <= 80.0\ngini = 0.577\nsamples = 391\nvalue = [1, 10, 193, 164, 22, 1]'),
#  Text(0.3125, 0.125, 'gini = 0.585\nsamples = 324\nvalue = [1, 8, 140, 153, 21, 1]'),
#  Text(0.4375, 0.125, 'gini = 0.346\nsamples = 67\nvalue = [0, 2, 53, 11, 1, 0]'),
#  Text(0.75, 0.625, 'X[1] <= 0.335\ngini = 0.653\nsamples = 416\nvalue = [3, 16, 67, 205, 115, 10]'),
#  Text(0.625, 0.375, 'X[9] <= 10.75\ngini = 0.583\nsamples = 95\nvalue = [0, 1, 10, 31, 52, 1]'),
#  Text(0.5625, 0.125, 'gini = 0.531\nsamples = 8\nvalue = [0, 0, 5, 2, 1, 0]'),
#  Text(0.6875, 0.125, 'gini = 0.542\nsamples = 87\nvalue = [0, 1, 5, 29, 51, 1]'),
#  Text(0.875, 0.375, 'X[8] <= 0.575\ngini = 0.633\nsamples = 321\nvalue = [3, 15, 57, 174, 63, 9]'),
#  Text(0.8125, 0.125, 'gini = 0.658\nsamples = 83\nvalue = [3, 8, 31, 36, 5, 0]'),
#  Text(0.9375, 0.125, 'gini = 0.59\nsamples = 238\nvalue = [0, 7, 26, 138, 58, 9]')]

# %%
# instantiate the DecisionTreeClassifier model with criterion entropy
clf_en = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)
# fit the model
plt.figure(figsize=(20,15))
from sklearn import tree
tree.plot_tree(clf_en.fit(X_train, y_train))
# Out:
# [Text(0.5, 0.875, 'X[9] <= 10.525\nentropy = 1.728\nsamples = 1071\nvalue = [8, 38, 453, 422, 139, 11]'),
#  Text(0.25, 0.625, 'X[8] <= 0.575\nentropy = 1.385\nsamples = 655\nvalue = [5, 22, 386, 217, 24, 1]'),
#  Text(0.125, 0.375, 'X[6] <= 63.5\nentropy = 1.143\nsamples = 264\nvalue = [4, 12, 193, 53, 2, 0]'),
#  Text(0.0625, 0.125, 'entropy = 1.352\nsamples = 170\nvalue = [4, 12, 113, 39, 2, 0]'),
#  Text(0.1875, 0.125, 'entropy = 0.607\nsamples = 94\nvalue = [0, 0, 80, 14, 0, 0]'),
#  Text(0.375, 0.375, 'X[9] <= 9.85\nentropy = 1.441\nsamples = 391\nvalue = [1, 10, 193, 164, 22, 1]'),
#  Text(0.3125, 0.125, 'entropy = 1.179\nsamples = 239\nvalue = [0, 6, 138, 93, 2, 0]'),
#  Text(0.4375, 0.125, 'entropy = 1.662\nsamples = 152\nvalue = [1, 4, 55, 71, 20, 1]'),
#  Text(0.75, 0.625, 'X[8] <= 0.685\nentropy = 1.802\nsamples = 416\nvalue = [3, 16, 67, 205, 115, 10]'),
#  Text(0.625, 0.375, 'X[1] <= 1.015\nentropy = 1.773\nsamples = 231\nvalue = [3, 16, 50, 123, 38, 1]'),
#  Text(0.5625, 0.125, 'entropy = 1.651\nsamples = 223\nvalue = [0, 12, 49, 123, 38, 1]'),
#  Text(0.6875, 0.125, 'entropy = 1.406\nsamples = 8\nvalue = [3, 4, 1, 0, 0, 0]'),
#  Text(0.875, 0.375, 'X[9] <= 11.55\nentropy = 1.575\nsamples = 185\nvalue = [0, 0, 17, 82, 77, 9]'),
#  Text(0.8125, 0.125, 'entropy = 1.505\nsamples = 104\nvalue = [0, 0, 15, 57, 30, 2]'),
#  Text(0.9375, 0.125, 'entropy = 1.416\nsamples = 81\nvalue = [0, 0, 2, 25, 47, 7]')]
